# %%
import pandas as pd

# %%
annuaire_education_dataframe = pd.read_csv('data/fr-en-annuaire-education.csv', sep=';')
indicateur_resultat_lycee_dataframe = pd.read_csv('data/fr-en-indicateurs-de-resultat-des-lycees-gt_v2.csv', sep=';')

df = pd.merge(annuaire_education_dataframe, indicateur_resultat_lycee_dataframe, left_on='Identifiant_de_l_etablissement', right_on='UAI')

df
# Out:
# C:\Users\trist\AppData\Local\Temp\ipykernel_22256\844801828.py:1: DtypeWarning: Columns (18,19,20,39,41,60,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   annuaire_education_dataframe = pd.read_csv('data/fr-en-annuaire-education.csv', sep=';')
#       Identifiant_de_l_etablissement  \
# 0                           0951728M
# 1                           0951728M
# 2                           0951728M
# 3                           0951728M
# 4                           0951728M
# ...                              ...
# 27899                       0421034W
# 27900                       0421034W
# 27901                       0421034W
# 27902                       0660907C
# 27903                       0802140S
#
#                                        Nom_etablissement Type_etablissement  \
# 0                                   Lycée Edmond Rostand              Lycée
# 1                                   Lycée Edmond Rostand              Lycée
# 2                                   Lycée Edmond Rostand              Lycée
# 3                                   Lycée Edmond Rostand              Lycée
# 4                                   Lycée Edmond Rostand              Lycée
# ...                                                  ...                ...
# 27899       Lycée général et technologique privé Sévigné              Lycée
# 27900       Lycée général et technologique privé Sévigné              Lycée
# 27901       Lycée général et technologique privé Sévigné              Lycée
# 27902  Lycée technologique, annexe du lycée Pablo Pic...              Lycée
# 27903                 Micro-lycée de l'académie d'amiens              Lycée
#
#       Statut_public_prive            Adresse_1 Adresse_2  \
# 0                  Public      75 rue de Paris       NaN
# 1                  Public      75 rue de Paris       NaN
# 2                  Public      75 rue de Paris       NaN
# 3                  Public      75 rue de Paris       NaN
# 4                  Public      75 rue de Paris       NaN
# ...                   ...                  ...       ...
# 27899               Privé   4 rue JULES VALLES       NaN
# 27900               Privé   4 rue JULES VALLES       NaN
# 27901               Privé   4 rue JULES VALLES       NaN
# 27902              Public  Route Nationale 114       NaN
# 27903              Public        Rue Montaigne       NaN
#
#                       Adresse_3  Code_postal Code_commune  \
# 0                           NaN        95310        95572
# 1                           NaN        95310        95572
# 2                           NaN        95310        95572
# 3                           NaN        95310        95572
# 4                           NaN        95310        95572
# ...                         ...          ...          ...
# 27899  42023 ST ETIENNE CEDEX 2        42023        42218
# 27900  42023 ST ETIENNE CEDEX 2        42023        42218
# 27901  42023 ST ETIENNE CEDEX 2        42023        42218
# 27902               66200 THEZA        66200        66208
# 27903              80080 AMIENS        80080        80021
#
#                Nom_commune  ... Valeur ajoutee du taux de mentions - S2TMD  \
# 0      Saint-Ouen-l'Aumône  ...                                        NaN
# 1      Saint-Ouen-l'Aumône  ...                                        NaN
# 2      Saint-Ouen-l'Aumône  ...                                        NaN
# 3      Saint-Ouen-l'Aumône  ...                                        NaN
# 4      Saint-Ouen-l'Aumône  ...                                        NaN
# ...                    ...  ...                                        ...
# 27899        Saint-Etienne  ...                                        NaN
# 27900        Saint-Etienne  ...                                        NaN
# 27901        Saint-Etienne  ...                                        NaN
# 27902                Théza  ...                                        NaN
# 27903               Amiens  ...                                        NaN
#
#        Valeur ajoutee du taux de mentions - STHR  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 27899                                        NaN
# 27900                                        NaN
# 27901                                        NaN
# 27902                                        NaN
# 27903                                        NaN
#
#        Nombre de mentions TB avec felicitations - G  \
# 0                                               2.0
# 1                                               1.0
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 27899                                           NaN
# 27900                                           NaN
# 27901                                           NaN
# 27902                                           NaN
# 27903                                           NaN
#
#        Nombre de mentions TB sans felicitations - G  Nombre de mentions B - G  \
# 0                                              11.0                      24.0
# 1                                               4.0                      28.0
# 2                                               NaN                       NaN
# 3                                               NaN                       NaN
# 4                                               NaN                       NaN
# ...                                             ...                       ...
# 27899                                           NaN                       NaN
# 27900                                           NaN                       NaN
# 27901                                           NaN                       NaN
# 27902                                           NaN                       NaN
# 27903                                           NaN                       NaN
#
#        Nombre de mentions AB - G  \
# 0                           44.0
# 1                           47.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 27899                        NaN
# 27900                        NaN
# 27901                        NaN
# 27902                        NaN
# 27903                        NaN
#
#        Nombre de mentions TB avec felicitations - T  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 27899                                           NaN
# 27900                                           NaN
# 27901                                           NaN
# 27902                                           NaN
# 27903                                           NaN
#
#        Nombre de mentions TB sans felicitations - T Nombre de mentions B - T  \
# 0                                               NaN                      7.0
# 1                                               NaN                      2.0
# 2                                               NaN                      NaN
# 3                                               NaN                      NaN
# 4                                               NaN                      NaN
# ...                                             ...                      ...
# 27899                                           NaN                      NaN
# 27900                                           NaN                      NaN
# 27901                                           NaN                      NaN
# 27902                                           NaN                      NaN
# 27903                                           NaN                      NaN
#
#       Nombre de mentions AB - T
# 0                          30.0
# 1                           8.0
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 27899                       NaN
# 27900                       NaN
# 27901                       NaN
# 27902                       NaN
# 27903                       NaN
#
# [27904 rows x 161 columns]
